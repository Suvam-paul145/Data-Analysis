# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# %%
# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=1000)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, label='2x', color='red', linewidth=1, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')
plt.legend()
plt.show()

# %%
plt.plot(x,y, 'b^-.', label='2x')

# %%
x2 = np.arange(0,4.5,0.5)

# %%
# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
plt.legend()

# %%
x = np.arange(0,10000,0.5)
plt.plot(x, x**2, linestyle='--', markersize=10, label ='x^2')
plt.show()
plt.legend()
# Out:
# C:\Users\suvam\AppData\Local\Temp\ipykernel_16548\626432048.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# %%
# Add a title (specify font parameters with fontdict)
plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Our First Graph!')

# %%
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16548\1100316908.py in ?()
#       1 fifa = pd.read_csv('fifa_data.csv')
#       2
# ----> 3 fifa.display()
#
# c:\Users\suvam\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'display'

# %%
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa.Overall, bins=bins, color="#96e999")

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

labels = ['Left', 'Right']
colors = ['#abcdef', '#aabbcc']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Foot Preference of FIFA Players')

plt.show()
# Out:
# /tmp/ipython-input-57-636778017.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
# /tmp/ipython-input-57-636778017.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,.4)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()
# Out:
# /tmp/ipython-input-58-2824485931.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa.loc[fifa.Weight < 125].count()[0]
# /tmp/ipython-input-58-2824485931.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
# /tmp/ipython-input-58-2824485931.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = fifa.loc[fifa.Club == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']

#bp = plt.boxplot([barcelona, madrid, revs], labels=['a','b','c'], boxprops=dict(facecolor='red'))
bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})

plt.arange(0,110,10)
plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

for box in bp['boxes']:
    # change outline color
    box.set(color='#4286f4', linewidth=2)
    # change fill color
    box.set(facecolor = '#abcdef' )
    # change hatch
    #box.set(hatch = '/')

plt.show()
# Out:
# /tmp/ipython-input-64-1671150609.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})
# /tmp/ipython-input-64-1671150609.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-64-1671150609.py in <cell line: 0>()
#      11
#      12 plt.legend()
# ---> 13 plt.arange(0,110,10)
#      14 plt.title('Professional Soccer Team Comparison')
#      15 plt.ylabel('FIFA Overall Rating')
#
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
print(plt.xticks())  # Get current x-tick locations and labels
print(plt.yticks())  # Get current y-tick locations and labels
# Out:
# (array([0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25]), [Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00'), Text(1.25, 0, '1.25'), Text(1.5, 0, '1.50'), Text(1.75, 0, '1.75'), Text(2.0, 0, '2.00'), Text(2.25, 0, '2.25'), Text(2.5, 0, '2.50'), Text(2.75, 0, '2.75'), Text(3.0, 0, '3.00'), Text(3.25, 0, '3.25')])
# (array([3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25]), [Text(0, 3.75, '3.75'), Text(0, 4.0, '4.00'), Text(0, 4.25, '4.25'), Text(0, 4.5, '4.50'), Text(0, 4.75, '4.75'), Text(0, 5.0, '5.00'), Text(0, 5.25, '5.25'), Text(0, 5.5, '5.50'), Text(0, 5.75, '5.75'), Text(0, 6.0, '6.00'), Text(0, 6.25, '6.25')])

# %%
# prompt: create one graph of elipse

t = np.linspace(0, 2*np.pi, 100)
a = 5  # Semi-major axis
b = 3  # Semi-minor axis
x = a * np.cos(t)
y = b * np.sin(t)

plt.figure(figsize=(6, 6))
plt.plot(x, y)
plt.title('Ellipse')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axis('equal')  # Ensures the ellipse is not distorted
plt.show()

# %%
# prompt: create one graph of elipse

t = np.linspace(0, 2*np.pi, 100)
a = 5  # Semi-major axis
b = 3  # Semi-minor axis
x = a * np.cos(t)
y = b * np.sin(t)

plt.figure(figsize=(6, 6))
plt.plot(x, y)
plt.title('Ellipse')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axis('equal')  # Ensures the ellipse is not distorted
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
print(plt.xticks())  # Get current x-tick locations and labels
print(plt.yticks())  # Get current y-tick locations and labels
plt.subplot(1,2,1) #making a subplot


# prompt: create one graph of elipse

t = np.linspace(0, 2*np.pi, 100)
a = 5  # Semi-major axis
b = 3  # Semi-minor axis
x = a * np.cos(t)
y = b * np.sin(t)

plt.figure(figsize=(6, 6))
plt.plot(x, y)
plt.title('Ellipse')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axis('equal')  # Ensures the ellipse is not distorted
plt.show()
plt.subplot(1,2,2) #making a subplot
# Out:
# (array([0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25]), [Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00'), Text(1.25, 0, '1.25'), Text(1.5, 0, '1.50'), Text(1.75, 0, '1.75'), Text(2.0, 0, '2.00'), Text(2.25, 0, '2.25'), Text(2.5, 0, '2.50'), Text(2.75, 0, '2.75'), Text(3.0, 0, '3.00'), Text(3.25, 0, '3.25')])
# (array([3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25]), [Text(0, 3.75, '3.75'), Text(0, 4.0, '4.00'), Text(0, 4.25, '4.25'), Text(0, 4.5, '4.50'), Text(0, 4.75, '4.75'), Text(0, 5.0, '5.00'), Text(0, 5.25, '5.25'), Text(0, 5.5, '5.50'), Text(0, 5.75, '5.75'), Text(0, 6.0, '6.00'), Text(0, 6.25, '6.25')])
# <Axes: >

# %%
# prompt: create a graph of sin and cos of taking random value

# Generate random x values
x = np.random.rand(100) * 2 * np.pi

# Calculate sin(x) and cos(x)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Sort the values by x for a clearer plot
sorted_indices = np.argsort(x)
x_sorted = x[sorted_indices]
y_sin_sorted = y_sin[sorted_indices]
y_cos_sorted = y_cos[sorted_indices]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_sorted, y_sin_sorted, label='sin(x)', color='blue')
plt.plot(x_sorted, y_cos_sorted, label='cos(x)', color='red')

# Add title and labels
plt.title('Sine and Cosine of Random Values')
plt.xlabel('Random Value (radians)')
plt.ylabel('Function Value')

# Add a legend
plt.legend()

# Add a grid
plt.grid(True)

# Show the plot
plt.show()

# %%
# prompt: create graph of tanx

x_tan = np.linspace(-np.pi/2 + 0.1, np.pi/2 - 0.1, 200) # Avoid vertical asymptotes
y_tan = np.tan(x_tan)

plt.figure(figsize=(8, 6))
plt.plot(x_tan, y_tan, label='tan(x)', color='green')

plt.title('Graph of tan(x)')
plt.xlabel('x (radians)')
plt.ylabel('tan(x)')

plt.grid(True)
plt.ylim(-10, 10) # Limit the y-axis to avoid extreme values near asymptotes

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create subplots: 1 row, 2 columns
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --------- Parabola: y = x^2 ---------
x = np.linspace(-5, 5, 100)
y = x**2

axes[0].plot(x, y, label='y = x²', color='purple')
axes[0].set_title('Graph of a Parabola')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].legend()
axes[0].grid(True)

# --------- tan(x) ---------
x_tan = np.linspace(-np.pi/2 + 0.1, np.pi/2 - 0.1, 200)  # Avoid asymptotes
y_tan = np.tan(x_tan)

axes[1].plot(x_tan, y_tan, label='tan(x)', color='green')
axes[1].set_title('Graph of tan(x)')
axes[1].set_xlabel('x (radians)')
axes[1].set_ylabel('tan(x)')
axes[1].grid(True)
axes[1].set_ylim(-10, 10)  # Limit y-axis
axes[1].legend()

# Show the final figure
plt.tight_layout()
plt.show()
