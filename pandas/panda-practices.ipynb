# %%
import numpy as np
import pandas as pd

# %%
city = pd.read_csv('cities_r2.csv')

# %%
city.info
# Out:
# <bound method DataFrame.info of      name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar           3          PUNJAB          9            145238
# 1        Achalpur          27     MAHARASHTRA          7            112293
# 2        Adilabad          28  ANDHRA PRADESH          1            117388
# 3       Adityapur          20       JHARKHAND         24            173988
# 4           Adoni          28  ANDHRA PRADESH         21            166537
# ..            ...         ...             ...        ...               ...
# 488  Vizianagaram          28  ANDHRA PRADESH         12            227533
# 489      Warangal          28  ANDHRA PRADESH          9            620116
# 490        Wardha          27     MAHARASHTRA          8            105543
# 491   Yamunanagar           6         HARYANA          3            216628
# 492      Yavatmal          27     MAHARASHTRA         14            116714
#
# ...

# %%
city.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0       Abohar           3          PUNJAB          9            145238
# 1     Achalpur          27     MAHARASHTRA          7            112293
# 2     Adilabad          28  ANDHRA PRADESH          1            117388
# 3    Adityapur          20       JHARKHAND         24            173988
# 4        Adoni          28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
city['name_of_city'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 493 entries, 0 to 492
# Series name: name_of_city
# Non-Null Count  Dtype
# --------------  -----
# 493 non-null    object
# dtypes: object(1)
# memory usage: 4.0+ KB

# %%
city['name_of_city'].describe()
# Out:
# count            493
# unique           492
# top       Aurangabad
# freq               2
# Name: name_of_city, dtype: object

# %%
city.sort_values(["state_code","dist_code"], ascending = [1,1]) #sorting the valaue of state code in ascending order
# Out:
#     name_of_city  state_code                 state_name  dist_code  \
# 445     Srinagar           1            JAMMU & KASHMIR         10
# 30      Anantnag           1            JAMMU & KASHMIR         14
# 231        Jammu           1            JAMMU & KASHMIR         21
# 431       Shimla           2           HIMACHAL PRADESH         11
# 66        Batala           3                     PUNJAB          1
# ..           ...         ...                        ...        ...
# 282      Kurichi          33                 TAMIL NADU         31
# 465     Tiruppur          33                 TAMIL NADU         32
# 357    Ozhukarai          34                 PUDUCHERRY          2
# 378   Puducherry          34                 PUDUCHERRY          2
# 376   Port Blair          35  ANDAMAN & NICOBAR ISLANDS          3
#
#      population_total  population_male  population_female  \
# 445           1192792           631916             560876
# ...

# %%
city.loc[city["literates_female"] >1000000].sort_values(["literates_female"], ascending = [1])
# Out:
#           name_of_city  state_code      state_name  dist_code  \
# 380               Pune          27     MAHARASHTRA         25
# 449              Surat          24         GUJARAT         25
# 274            Kolkata          19     WEST BENGAL         16
# 119            Chennai          33      TAMIL NADU          2
# 7            Ahmadabad          24         GUJARAT          7
# 184  Greater Hyderabad          28  ANDHRA PRADESH         99
# 72           Bengaluru          29       KARNATAKA         18
# 141              Delhi           7    NCT OF DELHI         99
# 185     Greater Mumbai          27     MAHARASHTRA         99
#
#      population_total  population_male  population_female  \
# 380           3115431          1602137            1513294
# 449           4462002          2538243            1923759
# 274           4486679          2362662            2124017
# 119           4681087          2357633            2323454
# ...
